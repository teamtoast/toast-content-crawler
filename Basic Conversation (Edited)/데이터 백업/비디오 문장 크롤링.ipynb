# %%
from bs4 import BeautifulSoup
import requests
import uuid

# 한 건의 대화에 대한 정보를 담는 객체입니다.
class Conversation:
    # 질문(Question), 응답(Answer) 두 변수로 구성됩니다.
    def __init__(self, contentName, contentType, question, answer):
        if len(question) > 0 and question[0] == ':':
            question = question[1:]
        if len(answer) > 0 and answer[0] == ':':
            answer = answer[1:]
        while len(question) > 0 and question[0] == ' ':
            question = question[1:]
        while len(answer) > 0 and answer[0] == ':':
            answer = answer[1:]
        self.contentName = contentName
        self.contentType = contentType
        self.question = question
        self.answer = answer
        
    def __str__(self):
        return "질문: " + self.question + "\n답변: " + self.answer + "\n"

# 한 건의 영어 대화 주제 링크를 담는 객체입니다.
class Subject:
    def __init__(self, number, title, link):
        self.number = number
        self.title = title
        self.link = link
        
    def __str__(self):
        return "번호: " + self.number + "\n제목: " + self.title + "\n답변: " + self.link + "\n"
    
# 모든 영어 대화 주제를 추출하는 함수입니다.
def get_subjects(number):
    subjects = []
    
    req = requests.get('http://www.elllo.org/video/' + number)
    html = req.text
    
    soup = BeautifulSoup(html, 'html.parser')
    divs = soup.findAll('div', {"class": "mobilelist"})
    
    for subject in divs:
        tags = subject.findAll('a')
        
        for tag in tags:
            title = tag.text
            if title == '':
                continue
            link = tag['href']
            s = Subject(number, title, link)
            # print(s) # 추출된 주제를 출력합니다.
            subjects.append(s)
            
    return subjects

# 특정 대화 주제의 대화 내용을 크롤링합니다.
def get_conversation(title, number, url):
    conversations = []
    
    req = requests.get('http://www.elllo.org/video/' + number + "/" + url)
    html = req.text
    
    soup = BeautifulSoup(html, 'html.parser')
    if soup.text.find("transcript") != -1: # 스크립트 자체가 페이지에 없으면 취소
        return conversations
    if len(soup.findAll('div', {"class": "transcript"})) < 1:
        return conversations
    sayings = soup.findAll('div', {"class": "transcript"})[0]
    strongs = sayings.findAll('strong') # strong에 들어간 사람 이름 정보 확인

    idx = 0
    while True:
        if idx + 1 >= len(strongs):
            break
        question = strongs[idx].nextSibling # 사람 이름 다음에 메시지가 등장
        answer = strongs[idx + 1].nextSibling
        idx = idx + 1
        if question == None or answer == None:
            continue
        c = Conversation(number + str(uuid.uuid4()), idx, str(question), str(answer))
        print(c) # 추출된 대화 내용을 출력합니다.
        conversations.append(c)
        
    return conversations

# %%
subjects = []

# 모든 영어 대화 주제 링크를 얻어냅니다.
for i in range(0, 20):
    print("(" + str(i) + " / " + str(19) + ")")
    subjects.extend(get_subjects(str(1001 + (i * 25))))

print("전체 대화 주제의 개수는 " + str(len(subjects)) + "개 입니다.")
# Out:
# (0 / 19)
# (1 / 19)
# (2 / 19)
# (3 / 19)
# (4 / 19)
# (5 / 19)
# (6 / 19)
# (7 / 19)
# (8 / 19)
# (9 / 19)
# (10 / 19)
# (11 / 19)
# (12 / 19)
# (13 / 19)
# (14 / 19)
# (15 / 19)
# (16 / 19)
# (17 / 19)
# (18 / 19)
# (19 / 19)
# 전체 대화 주제의 개수는 268개 입니다.

# %%
conversations = []

idx = 0
# 모든 대화 내용을 얻어냅니다.
for subject in subjects:
    print("(" + str(idx) + "/" + str(len(subjects)) + ") 현재 주제: " + subject.title + "\n")
    conversations.extend(get_conversation(subject.title, subject.number, subject.link))
    idx = idx + 1
    
print("전체 대화 주제의 개수는 " + str(len(conversations)) + "개 입니다.")
# Out:
# (0/268) 현재 주제: Do teachers praise students too much?
#
# (1/268) 현재 주제: Do you prefer to read online or offline?
#
# (2/268) 현재 주제: Do you read fewer books because of the internet?
#
# (3/268) 현재 주제: What is being threatened in your country?
#
# 질문: Hi, I'm Jingwei.
# 답변:  I'm Joseph.
#
# 질문: I'm Joseph.
# 답변:  We're from Singapore and this is for elllo.org. The question today is what is being threatened in our country?
#
# 질문: We're from Singapore and this is for elllo.org. The question today is what is being threatened in our country?
# 답변:  I assume this refers to animals, and as of now I really can't think of any. The Singapore is doing a pretty good job, but in the past â¦
#
# 질문: I assume this refers to animals, and as of now I really can't think of any. The Singapore is doing a pretty good job, but in the past â¦
# 답변:  We had tigers ...
#
# 질문: We had tigers ...
# 답변:  But they're all gone now, except for at the zoo. We had quite a few species of snakes like grass snakes, but we don't see them around much now. Hopefully, some household pests like cockroaches, ants, maybe they'll be extinct soon. Then we could all have a more comfortable and less fearful lives. Any animals that you wanna see be threatened?
#
# 질문: But they're all gone now, except for at the zoo. We had quite a few species of snakes like grass snakes, but we don't see them around much now. Hopefully, some household pests like cockroaches, ants, maybe they'll be extinct soon. Then we could all have a more comfortable and less fearful lives. Any animals that you wanna see be threatened?
# 답변:  What?
#
# 질문: What?
# 답변:  I don't know.
#
# 질문: I don't know.
# 답변:  That's not politically correct.
#
# 질문: That's not politically correct.
# 답변:  Yeah, but I'm not a big fan of all animals. Dogs and cats, they're still alright but the big ones are scary ones.
#
# 질문: Yeah, but I'm not a big fan of all animals. Dogs and cats, they're still alright but the big ones are scary ones.
# 답변:  I think some bats, and some birds and some insects are being threatened in Singapore. But we don't hear much about them.
#
# 질문: I think some bats, and some birds and some insects are being threatened in Singapore. But we don't hear much about them.
# 답변:  So I guess they are still doing fine.
#
# (4/268) 현재 주제: What animals are dangerous in your country?
#
# 질문: Hi, I'm Jingwei.
# 답변:  I'm Joseph.
#
# 질문: I'm Joseph.
# 답변:  We're both from Singapore and this is for elllo.org. The question today isâ¦.
#
# 질문: We're both from Singapore and this is for elllo.org. The question today isâ¦.
# 답변:  Well, are there any dangerous animals in your country?
#
# 질문: Well, are there any dangerous animals in your country?
# 답변:  Huh, we don't see much animals. Snakes probably. Or the monitor lizard. It's a huge lizard. It can grow up to maybe four meters.
#
# 질문: Huh, we don't see much animals. Snakes probably. Or the monitor lizard. It's a huge lizard. It can grow up to maybe four meters.
# 답변:  I guess, but like when our canoeist paddle in the reservoir, they see the monitor lizards frequently but they are rather docile to be honest, so they wouldn't be one of the more dangerous animals to me. To me one of the most dangerous animals would probably be the household cat.
#
# 질문: I guess, but like when our canoeist paddle in the reservoir, they see the monitor lizards frequently but they are rather docile to be honest, so they wouldn't be one of the more dangerous animals to me. To me one of the most dangerous animals would probably be the household cat.
# 답변:  The household cat.
#
# 질문: The household cat.
# 답변:  Well ...
#
# 질문: Well ...
# 답변:  The domesticated cat?
#
# 질문: The domesticated cat?
# 답변:  Yep, I mean, you look at it and it's all cute and you don't think it can do anything, and then suddenly like, whoa, it jumps out of nowhere. Yeah, it can be pretty dangerous.
#
# 질문: Yep, I mean, you look at it and it's all cute and you don't think it can do anything, and then suddenly like, whoa, it jumps out of nowhere. Yeah, it can be pretty dangerous.
# 답변:  That's because you scare them.
#
# 질문: That's because you scare them.
# 답변:  Well, I guess it's kind of my fault. But yeah, cat's can be really dangerous if you don't handle them well.
#
# (5/268) 현재 주제: What is life like on a military base?
#
# (6/268) 현재 주제: Where is your favorite holiday resort?
#
# (7/268) 현재 주제: Who do you admire?
#
# (8/268) 현재 주제: Who do you admire?
#
# (9/268) 현재 주제: Do you enjoy being an expat?
#
# (10/268) 현재 주제: What foreign culture has a big influence in your country?
#
# (11/268) 현재 주제: Is you country multicultural?
#
# 질문: Hi, I'm Jingwei.
# 답변:  And I'm Joseph.
#
# 질문: And I'm Joseph.
# 답변:  We're both from Singapore and this is for elllo.org.
#
# 질문: We're both from Singapore and this is for elllo.org.
# 답변:  Yeah, today's question is is your country multicultural?
#
# 질문: Yeah, today's question is is your country multicultural?
# 답변:  Definitely. We have four official languages: Malay, Tamil, English and Chinese. So that's an indication of how multiracial we are. We also have many public holidays like the Malay New Year called ...... the Indian New Year, Depavali, Chinese New Year.
#
# 질문: Definitely. We have four official languages: Malay, Tamil, English and Chinese. So that's an indication of how multiracial we are. We also have many public holidays like the Malay New Year called ...... the Indian New Year, Depavali, Chinese New Year.
# 답변:  Festival of Lights.
#
# 질문: Festival of Lights.
# 답변:   Oops, not New Year. Festival of Lights. Somewhat like New Year.
#
# 질문: Oops, not New Year. Festival of Lights. Somewhat like New Year.
# 답변:  It's a traditional holiday and the Chinese New Year which involves these!
#
# 질문: It's a traditional holiday and the Chinese New Year which involves these!
# 답변:  Anpow.
#
# 질문: Anpow.
# 답변:  There's always money inside so it's a very happy New Year for the Chinese. I guess we can also tell them about multicultural. Because now schools, we often sing songs like for ..... Yeah, ...... is one of the more popular Malay songs, and we have our Chinese songs. Yeah, I guess learning about all these different cultures, definitely shows that we are multicultural, so Singapore is one of the more multicultural countries.
#
# (12/268) 현재 주제: Are there any regional rivalries in your country?
#
# (13/268) 현재 주제: What are your favorite pizza toppings?
#
# (14/268) 현재 주제: How does your hometown differ?
#
# (15/268) 현재 주제: What is good about your hometown?
#
# 질문: Hi, I'm Doron from England, and you are?
# 답변:  I am Pernese from Jamaica.
#
# 질문: I am Pernese from Jamaica.
# 답변:  And our question is what is good about your hometown?
#
# 질문: And our question is what is good about your hometown?
# 답변:  My hometown is Kingston and it's a really exciting place to be. There's always a party happening like every night, so it's just really lively, really good for culture. How about yours?
#
# 질문: My hometown is Kingston and it's a really exciting place to be. There's always a party happening like every night, so it's just really lively, really good for culture. How about yours?
# 답변:  My hometown is a place called South-End-on-Sea and I think there's a clue in the name because I love being by the sea and so â¦ in fact I can just go to the beach anytime. During the one week of summer anyway. We don't have a lot of hot weather. That's probably the best thing for me.
#
# (16/268) 현재 주제: How long should the school day be?
#
# (17/268) 현재 주제: Do you use any special beauty products?
#
# (18/268) 현재 주제: Do you prefer coffee or tea?
#
# 질문: Hello, this is Diego from Mexico.
# 답변:  And Elena from Bulgaria.
#
# 질문: And Elena from Bulgaria.
# 답변:  For elllo.org. Today, we're going to have a really interesting question. Do you prefer coffee or tea?
#
# 질문: For elllo.org. Today, we're going to have a really interesting question. Do you prefer coffee or tea?
# 답변:  That's a difficult one. I used to not like coffee for a really long time and then I started drinking coffee and I couldn't stop, and I used to have like three or four cups of coffee a day and at the end, I wasn't able to sleep at night, so I stopped drinking coffee, and now I prefer tea. What do you prefer?
#
# 질문: That's a difficult one. I used to not like coffee for a really long time and then I started drinking coffee and I couldn't stop, and I used to have like three or four cups of coffee a day and at the end, I wasn't able to sleep at night, so I stopped drinking coffee, and now I prefer tea. What do you prefer?
# 답변:  I don't know. For me it used to be the other way around. I was a coffee addict. I have to have my frappacino in the afternoon, my Americano in the morning and all these different types of coffee in the day, but then eventually I got the same problem. I wasn't able to fall asleep, but you know I found out that tea actually has caffeine in it, so it has the same effect, so I guess it really depends on the day. If I'm really sleepy and I need to wake up in the morning, I prefer coffee but if it's just to relax at night, I would rather have a cup of tea.
#
# 질문: I don't know. For me it used to be the other way around. I was a coffee addict. I have to have my frappacino in the afternoon, my Americano in the morning and all these different types of coffee in the day, but then eventually I got the same problem. I wasn't able to fall asleep, but you know I found out that tea actually has caffeine in it, so it has the same effect, so I guess it really depends on the day. If I'm really sleepy and I need to wake up in the morning, I prefer coffee but if it's just to relax at night, I would rather have a cup of tea.
# 답변:  That's great.
#
# 질문: That's great.
# 답변:  Yeah. What do you guys prefer?
#
# (19/268) 현재 주제: Should sports focus on winning?
# (20/268) 현재 주제: Why you should stay in shape?
#
# (21/268) 현재 주제: How do people show affection in your country?
#
# (22/268) 현재 주제: Are you touchy-feely?
#
# (23/268) 현재 주제: Are you a tree hugger?
#
# (24/268) 현재 주제: What is your country's biggest environmental problem?
#
# (25/268) 현재 주제: What do you like shopping for?
#
# (26/268) 현재 주제: Do you tend to hold onto things?
#
# 질문: Hi, everyone I'm Danny from England.
# 답변:  And I'm Alex from Australia. And were going to be talking about whether or not we hoard things. Now Danny do you hoard things?
#
# 질문: And I'm Alex from Australia. And were going to be talking about whether or not we hoard things. Now Danny do you hoard things?
# 답변:  Oh, all the time. I have so many papers everywhere, so many books. All my receipts, just anything that I've bought that's special to me. All of them in one big box.
#
# 질문: Oh, all the time. I have so many papers everywhere, so many books. All my receipts, just anything that I've bought that's special to me. All of them in one big box.
# 답변:  Really, well, I tend to keep my clothes even though they're well past their use-by dates
#
# 질문: Really, well, I tend to keep my clothes even though they're well past their use-by dates
# 답변:  Oh, me too. I once had this t-shirt a friend bought me and I wouldn't throw  it out and eventually my mom had to throw it out cause there were holes in it.
#
# 질문: Oh, me too. I once had this t-shirt a friend bought me and I wouldn't throw  it out and eventually my mom had to throw it out cause there were holes in it.
# 답변:  Oh, no.
#
# 질문: Oh, no.
# 답변:  Really, yeah. So what is the one item you've had the longest?
#
# 질문: Really, yeah. So what is the one item you've had the longest?
# 답변:  One item I've had the longest is probably this really disgusting teddy bear that I've had since I was three.
#
# 질문: One item I've had the longest is probably this really disgusting teddy bear that I've had since I was three.
# 답변:  Oh, really.
#
# 질문: Oh, really.
# 답변: It's been through the wash so many times.
#
# 질문: It's been through the wash so many times.
# 답변:  It's not falling apart is it?
#
# 질문: It's not falling apart is it?
# 답변:  It is falling apart. Yeah.
#
# (27/268) 현재 주제: What do you want to get rid of?
#
# (28/268) 현재 주제: What can you do for hours on end?
#
# (29/268) 현재 주제: Do you bottle stuff up?
#
# (30/268) 현재 주제: Do men or women hold hands where you live?
#
# (31/268) 현재 주제: How do people in Sri Lanka show affection?
#
# (32/268) 현재 주제: Have you ever went camping in the wild?
#
# 질문: Hi, guys I'm Danny from England.
# 답변: And I'm Alex from Australia. Danny have you ever been camping in the wild?
#
# 질문: And I'm Alex from Australia. Danny have you ever been camping in the wild?
# 답변:  Not really. I went with the guides to go camping but it wasn't really that great. What about you?
#
# 질문: Not really. I went with the guides to go camping but it wasn't really that great. What about you?
# 답변:  I've done quite a bit of camping. When I was young I was in scouts, so when I went camping in Australia, but I've also been camping in Africa. I've been camping in Botswana, Zimbabwe and Zambia with my family.
#
# 질문: I've done quite a bit of camping. When I was young I was in scouts, so when I went camping in Australia, but I've also been camping in Africa. I've been camping in Botswana, Zimbabwe and Zambia with my family.
# 답변:  Really. Wow! I'm so afraid to camping I think because of the bugs.
#
# 질문: Really. Wow! I'm so afraid to camping I think because of the bugs.
# 답변:  Oh, the bugs are not too bad. You kind of get used to them after awhile
#
# 질문: Oh, the bugs are not too bad. You kind of get used to them after awhile
# 답변:  But they're hideous and they're horrible.
#
# 질문: But they're hideous and they're horrible.
# 답변:  Well, especially in Australia, the bugs are very big so you're going to have to get used to that.
#
# 질문: Well, especially in Australia, the bugs are very big so you're going to have to get used to that.
# 답변: OK, I'm not going camping.
#
# (33/268) 현재 주제: Are you a nature lover?
#
# (34/268) 현재 주제: Action or relaxation?
#
# (35/268) 현재 주제:  What is a cool holiday where you live?
#
# (36/268) 현재 주제: Who is a famous folk hero from your country?
#
# (37/268) 현재 주제: Have you ever had to stand up for yourself?
#
# (38/268) 현재 주제: Would like to be a singer, actor, or athlete?
#
# 질문: Hi, my name is Tlotlo, and I am from Botswana.
# 답변:  Hey, I'm Rese from Botswana as well.
#
# 질문: Hey, I'm Rese from Botswana as well.
# 답변:  So our question is would your rather be a famous singer, actor, athlete or politician?
#
# 질문: So our question is would your rather be a famous singer, actor, athlete or politician?
# 답변:  I think I'd rather be a famous actor cause you get a lot of money, you're famous but you don't do that much. If you're an athlete you have to work hard, and you're always tired.
#
# 질문: I think I'd rather be a famous actor cause you get a lot of money, you're famous but you don't do that much. If you're an athlete you have to work hard, and you're always tired.
# 답변:  But what about learning scripts? That sounds like a really difficult job to me?
#
# 질문: But what about learning scripts? That sounds like a really difficult job to me?
# 답변: But you learn bit by bit cause shooting is over a long time so maybe it's not so hard.
#
# 질문: But you learn bit by bit cause shooting is over a long time so maybe it's not so hard.
# 답변:  Yeah, but I would really say hey, that being an actor is actually pretty hard cause there's a lot that comes with it, acting out a part that you probably are sometimes not very familiar with that should take a lot of out you. You know? So it should be a hard job.
#
# 질문: Yeah, but I would really say hey, that being an actor is actually pretty hard cause there's a lot that comes with it, acting out a part that you probably are sometimes not very familiar with that should take a lot of out you. You know? So it should be a hard job.
# 답변:  You just have to be good at being fake.
#
# 질문: You just have to be good at being fake.
# 답변:  Well, you could put it that way. Well, I think I 'd rather be a famous singer. I wish I was good at singing though, but that's what I need. I just all about spreading the love and sharing my thoughts with other people and just expressing my mind, and I think singers have the opportunity to share what's in their minds. Express themselves, share the love, you know, and I think that's what I'd much rather do, just spread the word. I'm all about words. I think words have a very, very big effect on people. Yeah, what you say really does matter, so being a singer you can actually say a lot and touch a lot people's hearts. That's my destiny in life. I want to touch many hearts. Yeah, so a singer for me.
#
# (39/268) 현재 주제:  Who is a celebrity you like?
#
# (40/268) 현재 주제: Do you like beards?
#
# (41/268) 현재 주제: Would you like to grow a beard?
#
# (42/268) 현재 주제: Have you ever been a babysitter?
#
# 질문: Hello, Silvia. This is Diego from Mexico.
# 답변:  Hi. I'm Silvia from Guatemala.
#
# 질문: Hi. I'm Silvia from Guatemala.
# 답변:  And I want to ask you a question today. I want to ask you, "Have you ever been a baby sitter?"
#
# 질문: And I want to ask you a question today. I want to ask you, "Have you ever been a baby sitter?"
# 답변:  Yes, I've been a babysitter. And actually, I was seventeen, so almost eight years ago, and I was in high school, and after school, I would go home, and my cousin would leave her little daughter with me, a two-year old, and she just learned how to walk so imagine that, and it was quite exhausting
#
# 질문: Yes, I've been a babysitter. And actually, I was seventeen, so almost eight years ago, and I was in high school, and after school, I would go home, and my cousin would leave her little daughter with me, a two-year old, and she just learned how to walk so imagine that, and it was quite exhausting
# 답변:  She was a handful.
#
# 질문: She was a handful.
# 답변:  Yeah, she was.
#
# 질문: Yeah, she was.
# 답변:  Did you get paid for this?
#
# 질문: Did you get paid for this?
# 답변:  No, I just liked her so much. I liked taking care of her even though sometimes she drove me crazy, and I felt like spanking her, but in the end I just ended spending the afternoon with her.
#
# 질문: No, I just liked her so much. I liked taking care of her even though sometimes she drove me crazy, and I felt like spanking her, but in the end I just ended spending the afternoon with her.
# 답변:  Ah, OK, sounds very good.
#
# 질문: Ah, OK, sounds very good.
# 답변:  It was OK, I guess.
#
# (43/268) 현재 주제: Do you like to take naps?
# (44/268) 현재 주제: Do you believe in conspiracies?
#
# 질문: Hi, this is Paul from South Korea.
# 답변:  And I'm Hanna from Australia.
#
# 질문: And I'm Hanna from Australia.
# 답변:  So Hanna, do you believe in conspiracies?
#
# 질문: So Hanna, do you believe in conspiracies?
# 답변:  Conspiracies? I like to read about conspiracies, and I really like watching all those conspiracy theory videos on youtube, but I'm not really convinced to be honest. Yeah, I don't really believe it's true. I don't know. It's really difficult because there's never enough information
#
# 질문: Conspiracies? I like to read about conspiracies, and I really like watching all those conspiracy theory videos on youtube, but I'm not really convinced to be honest. Yeah, I don't really believe it's true. I don't know. It's really difficult because there's never enough information
# 답변: Yeah, all these rumors people are talking about.
#
# 질문: Yeah, all these rumors people are talking about.
# 답변:  Yeah, exactly, a lot of it just seems like a rumor to m
#
# (45/268) 현재 주제: Should we go to the moon?
#
# (46/268) 현재 주제: Are any animals protected in your country?
#
# (47/268) 현재 주제: Have you been stopped by the police?
#
# 질문: Hello, this is Diego from Mexico.
# 답변:  Hello, this is Silvia from Guatemala.
#
# 질문: Hello, this is Silvia from Guatemala.
# 답변:  And today I'm going to ask Silvia if she has ever been stopped by the police.
#
# 질문: And today I'm going to ask Silvia if she has ever been stopped by the police.
# 답변:  Yes, I've been stopped by the police, and actually â¦ No the thing is in Guatemala we have checkpoints. They wanna see if you have your driver's license. You know, if it's not expired or anything and that day, guess what?
#
# 질문: Yes, I've been stopped by the police, and actually â¦ No the thing is in Guatemala we have checkpoints. They wanna see if you have your driver's license. You know, if it's not expired or anything and that day, guess what?
# 답변:  You didn't have your driver's license.
#
# 질문: You didn't have your driver's license.
# 답변:  I grabbed another wallet, and I was running to go someplace, so I grabbed an empty wallet, so I had no ID, no driver's license, no money.
#
# 질문: I grabbed another wallet, and I was running to go someplace, so I grabbed an empty wallet, so I had no ID, no driver's license, no money.
# 답변:  That's a very bad combination.
#
# 질문: That's a very bad combination.
# 답변:  I know.
#
# 질문: I know.
# 답변:  OK.
#
# 질문: OK.
# 답변:  And they stopped me and asked for my driver's license, and I looked for it and I didn't have it.
#
# 질문: And they stopped me and asked for my driver's license, and I looked for it and I didn't have it.
# 답변:  And what did you do?
#
# 질문: And what did you do?
# 답변:  I just told him, really, I'm 25. I have an driver's license. And so, "You don't look 25"
#
# 질문: I just told him, really, I'm 25. I have an driver's license. And so, "You don't look 25"
# 답변:  OK
#
# 질문: OK
# 답변:  "What's your driver's license number?" I have no idea. "What's the letter in the beginning of your driver's license?" We have like some letters, and it's for the type of license you have, and I had no idea what he was talking about, because the way he said it, I didn't realize we was asking for the type. He said, "What's the first letter?" And I was thinking OK, maybe it's a combination of numbers and letters, and so he gave me a ticket.
#
# 질문: "What's your driver's license number?" I have no idea. "What's the letter in the beginning of your driver's license?" We have like some letters, and it's for the type of license you have, and I had no idea what he was talking about, because the way he said it, I didn't realize we was asking for the type. He said, "What's the first letter?" And I was thinking OK, maybe it's a combination of numbers and letters, and so he gave me a ticket.
# 답변:  Oh, was it expensive?
#
# 질문: Oh, was it expensive?
# 답변:  Yes, of course it was expensive. So I never get stopped and the day I got stopped, I didn't have my driver's license.
#
# 질문: Yes, of course it was expensive. So I never get stopped and the day I got stopped, I didn't have my driver's license.
# 답변:  That's a really bad experience.
#
# (48/268) 현재 주제: What is your favorite holiday?
#
# (49/268) 현재 주제: What is your favorite holiday?
#
# 질문: Hello, this is Mike from Singapore, and this is for elllo.org, and we're talking to ...
# 답변:  MJ from Korea.
#
# 질문: MJ from Korea.
# 답변:  MJ from Korea. OK. Well, we're going to talk about holiday. Do you have lots of holidays in your country?
#
# 질문: MJ from Korea. OK. Well, we're going to talk about holiday. Do you have lots of holidays in your country?
# 답변:  Compared to America, we don't have a lot, but I think we have pretty a lot.
#
# 질문: Compared to America, we don't have a lot, but I think we have pretty a lot.
# 답변:  OK, for example.
#
# 질문: OK, for example.
# 답변:  For example, there is Salan which is celebrating the New Year, so we are eating some special kind of traditional food of Korea and there are some other, like, big event, traditional holidays in Korea and we're celebrating it. What about you Mike?
#
# 질문: For example, there is Salan which is celebrating the New Year, so we are eating some special kind of traditional food of Korea and there are some other, like, big event, traditional holidays in Korea and we're celebrating it. What about you Mike?
# 답변:  In Singapore we have holidays for the Chinese. We have holidays for the Malays and Indians, and there's three groups, they make up like probably almost the biggest percentage in Singapore, and so for example a Chinese holiday would be Chinese New Year of course. That's the main one, and for Indians there is a holiday called Depavali and that is nice as well. Lots of lights and for Malay they have holidays also. Well, it's the equivalent of the Malay New Year and there's a lot of good food. It's very interesting stuff. Really.
#
# (50/268) 현재 주제: Do video games lower or raise crime?
#
# (51/268) 현재 주제: Do you like to hold a party?
#
# (52/268) 현재 주제: What is the last party you went to?
#
# (53/268) 현재 주제: Do you listen to podcasts?
#
# (54/268) 현재 주제: What makes a good DJ?
#
# (55/268) 현재 주제: Would your country be a good World Cup host?
#
# (56/268) 현재 주제: What country should have the World Cup?
#
# (57/268) 현재 주제: What did you want to be as a kid?
#
# (58/268) 현재 주제: What is the right age to drink alcohol?
#
# (59/268) 현재 주제: Should food have warning labels?
#
# 질문: Hi, my name is Chris.  I'm from the United States.
# 답변:   Hi, my name is Phoebe and I'm from China.
#
# 질문: Hi, my name is Phoebe and I'm from China.
# 답변:   Our question is should food have warning labels?  I definitely think so.  Think about all the awful things that are in food, especially processed food like high fructose corn syrup and other things that are so bad for you.  I mean consumers need to be empowered by having access to this kind of information, don't you think so?
#
# 질문: Our question is should food have warning labels?  I definitely think so.  Think about all the awful things that are in food, especially processed food like high fructose corn syrup and other things that are so bad for you.  I mean consumers need to be empowered by having access to this kind of information, don't you think so?
# 답변:   Yes, I think I totally agree with you but I think this kind of thing is they put labels only on the fast food but let's think in China you don't have a lot of fast food.  You go to a restaurant, in China we like hot teas, hot soup and they bring you something really hot, they're not going to put a label on the bowl so sometimes you don't know you just drink it.  One time what happened to me, my tongue was totally hurt and I couldn't enjoy the rest of the meal so what would you do in that case?
#
# 질문: Yes, I think I totally agree with you but I think this kind of thing is they put labels only on the fast food but let's think in China you don't have a lot of fast food.  You go to a restaurant, in China we like hot teas, hot soup and they bring you something really hot, they're not going to put a label on the bowl so sometimes you don't know you just drink it.  One time what happened to me, my tongue was totally hurt and I couldn't enjoy the rest of the meal so what would you do in that case?
# 답변:   They could put the nutritional facts on the menu.
#
# 질문: They could put the nutritional facts on the menu.
# 답변:   That might work.
#
# 질문: That might work.
# 답변:   Maybe that's a good idea.
#
# (60/268) 현재 주제: Have you ever been in a courtroom?
# (61/268) 현재 주제: Would you ever want to be a lawyer?
#
# (62/268) 현재 주제: Do you believe in the justice system?
#
# (63/268) 현재 주제: Have you been to Argentina?
#
# (64/268) 현재 주제: Are you good at managing your time?
#
# (65/268) 현재 주제: What do you think of homeschooling?
#
# (66/268) 현재 주제: Have you raised an animal?
#
# (67/268) 현재 주제: Did you ever go to camp?
#
# (68/268) 현재 주제: What renewable energies do you use?
#
# (69/268) 현재 주제: Do you think we will ever stop using oil?
#
# (70/268) 현재 주제: What are the main parties in your country?
#
# (71/268) 현재 주제: What is controversial in your country?
#
# (72/268) 현재 주제: How do you feel about guns?
#
# (73/268) 현재 주제: Does your country have good healthcare?
#
# (74/268) 현재 주제: What's your favorite national holiday?
#
# (75/268) 현재 주제: What career would you like to have?
#
# (76/268) 현재 주제: What is your dream job?
#
# (77/268) 현재 주제: Do people drive fast in your country?
#
# (78/268) 현재 주제: Are people safe drivers in my country?
#
# (79/268) 현재 주제: What do you like to eat for an energy boost?
#
# (80/268) 현재 주제: How are the road conditions in your area?
#
# (81/268) 현재 주제: How often do you ride your bike?
#
# (82/268) 현재 주제: Have you ever taken a memorable trip?
#
# (83/268) 현재 주제: Are you into social networking?
#
# (84/268) 현재 주제: Should children be allowed to use social media?
#
# (85/268) 현재 주제: Is your family on social media?
#
# (86/268) 현재 주제: How do you keep in touch with your family?
#
# (87/268) 현재 주제: Where would you like to visit?
#
# (88/268) 현재 주제: What  interesting place would you visit in your country?
#
# (89/268) 현재 주제: Do you like doing projects in teams?
#
# (90/268) 현재 주제: Are you good at taking tests?
#
# (91/268) 현재 주제: Had you had to rehab an injury?
#
# (92/268) 현재 주제: Do you like working out in gyms?
#
# (93/268) 현재 주제: Do you have money worries?
#
# (94/268) 현재 주제: Where would I like to live after retirement?
#
# (95/268) 현재 주제: Have you ever had a long distance relationship?
#
# (96/268) 현재 주제: Do you believe in love at first sight?
#
# (97/268) 현재 주제: What is fun to do in your hometown?
#
# (98/268) 현재 주제: What is your favorite place in your city?
#
# 질문: Hello.  My name is Aiste and I'm from Lithuania.  It's for elllo.org.  And now I want to talk about my favorite place in the city.  My favorite place in the city is the park.  I really like parks because parks are green.  Parks like nature inside of a big, big place.  In the park you can hide away from the smell of the cars and the noise from the fabrics and always when I'm in the city I always stop in the park for lunch.  I prefer much more buying some lunchboxes from the market and coming to eat in the park rather than sitting in cafe and being in one more building again.
# 답변:   May I say are you sitting in a park again?
#
# 질문: May I say are you sitting in a park again?
# 답변:   Yes.
#
# 질문: Yes.
# 답변:   Oh, you like the park, right?
#
# 질문: Oh, you like the park, right?
# 답변:   What's your favorite place in the city, Christophe?
#
# 질문: What's your favorite place in the city, Christophe?
# 답변:   I like the park too because they have swings there.
#
# 질문: I like the park too because they have swings there.
# 답변:  Yeah.
#
# 질문: Yeah.
# 답변:   Yeah, cool.
#
# 질문: Yeah, cool.
# 답변:   That's the best part right?
#
# 질문: That's the best part right?
# 답변:   That's the best everything.
#
# (99/268) 현재 주제: Praising Kids in School
#
# (100/268) 현재 주제: Were your parents strict?
#
# (101/268) 현재 주제: What kind of parent will you be?
#
# (102/268) 현재 주제: Have you ever found something valuable?
#
# (103/268) 현재 주제: Stranded on an Island
#
# 질문: I'm Seiji from Bolivia.
# 답변:   And I'm Olga from Mexico.
#
# 질문: And I'm Olga from Mexico.
# 답변:   Olga, if you were to go to a desert island for a long time...
#
# 질문: Olga, if you were to go to a desert island for a long time...
# 답변:   Hmm.
#
# 질문: Hmm.
# 답변:   Mention one thing that you would take.
#
# 질문: Mention one thing that you would take.
# 답변:   That's easy.  I would take my boyfriend.  Yeah, like I would, if I take him I won't get bored and he might hate me for taking him to a desert island forever but he eventually, we will eventually be, you know, happy together.
#
# 질문: That's easy.  I would take my boyfriend.  Yeah, like I would, if I take him I won't get bored and he might hate me for taking him to a desert island forever but he eventually, we will eventually be, you know, happy together.
# 답변:   That's good.
#
# 질문: That's good.
# 답변:   And you?
#
# 질문: And you?
# 답변:   Me, I would take a pocket knife.
#
# 질문: Me, I would take a pocket knife.
# 답변:   Oh, why?
#
# 질문: Oh, why?
# 답변:   Well, like in the movies, a pocket knife can be used for everything, in cutting trees and also building boats and different aeroplanes.
#
# 질문: Well, like in the movies, a pocket knife can be used for everything, in cutting trees and also building boats and different aeroplanes.
# 답변:   Yeah, you should build a boat for me and my boyfriend.
#
# 질문: Yeah, you should build a boat for me and my boyfriend.
# 답변:   Yeah, I'll make you do that.
#
# (104/268) 현재 주제: Metrosexual?
#
# (105/268) 현재 주제: Is it OK for men to cry?
#
# (106/268) 현재 주제: What subjectd did you hate?
#
# (107/268) 현재 주제: What kind of learner are you?
#
# (108/268) 현재 주제: Breaking bad Habits
#
# (109/268) 현재 주제: Do you have any bad habits
#
# (110/268) 현재 주제: What was the best party?
#
# (111/268) 현재 주제: Do you want a simple wedding
#
# (112/268) 현재 주제: Are people in your area  fit?
#
# (113/268) 현재 주제: Where would you like to hike?
#
# (114/268) 현재 주제: What is your worst experience?
#
# 질문: Hello.  My name is Aiste and I'm from Lithuania.  This is for elllo.org.
# 답변:   Yes, it is and I am Chris from Belgium and I want to know, Aiste, what is the worst experience that you ever had so far?
#
# 질문: Yes, it is and I am Chris from Belgium and I want to know, Aiste, what is the worst experience that you ever had so far?
# 답변:   Well, the one I can remember is that I had exam last week and...
#
# 질문: Well, the one I can remember is that I had exam last week and...
# 답변:   You had exam?
#
# 질문: You had exam?
# 답변:   Yes, and I wanted to go to exam.  I have to take bus for half an hour and I was waiting in the bus stop and the bus just passed me because it was too full.  There were so many people taking the same exam and the bus just passed me and didn't stop.  I was so angry and so worried.  I was afraid to be late for exam because the exam was very important and that was really unpleasant feeling.
#
# 질문: Yes, and I wanted to go to exam.  I have to take bus for half an hour and I was waiting in the bus stop and the bus just passed me because it was too full.  There were so many people taking the same exam and the bus just passed me and didn't stop.  I was so angry and so worried.  I was afraid to be late for exam because the exam was very important and that was really unpleasant feeling.
# 답변:   Oh, I would have been very, very angry.  So could you do your exam?
#
# 질문: Oh, I would have been very, very angry.  So could you do your exam?
# 답변:   Yeah.  Finally I was thinking all the time whether I should take taxi or wait for the next bus.  I decided to wait for the next bus.  It came and I was the last person that was able to enter the bus.
#
# 질문: Yeah.  Finally I was thinking all the time whether I should take taxi or wait for the next bus.  I decided to wait for the next bus.  It came and I was the last person that was able to enter the bus.
# 답변:   Oh my God.  You were so lucky.
#
# 질문: Oh my God.  You were so lucky.
# 답변:   I was lucky indeed.
#
# 질문: I was lucky indeed.
# 답변:   So after all it's not really a worse experience, a bad experience?
#
# 질문: So after all it's not really a worse experience, a bad experience?
# 답변:   It was a very bad experience but it ended in a good way luckily.
#
# 질문: It was a very bad experience but it ended in a good way luckily.
# 답변:   Yes.
#
# (115/268) 현재 주제: Have you ever been turned down?
#
# (116/268) 현재 주제: Is MMA too violent?
#
# (117/268) 현재 주제: What do you think about boxing?
#
# (118/268) 현재 주제: What do you think of martial arts?
#
# (119/268) 현재 주제: What is a traditional drink?
#
# (120/268) 현재 주제: Traditional Dance
#
# (121/268) 현재 주제: What can you cook well?
#
# (122/268) 현재 주제: Do you think protests work?
#
# (123/268) 현재 주제: How do you feel about  protests
#
# (124/268) 현재 주제: Is there lots of nature near you?
#
# (125/268) 현재 주제: Do you prefer local?
#
# (126/268) 현재 주제: How often to you eat out?
#
# (127/268) 현재 주제: What is the last movie you saw?
# (128/268) 현재 주제: What kind of movies do you like?
#
# (129/268) 현재 주제: Best town for weekend holidays?
#
# (130/268) 현재 주제: What is my country's best cities?
#
# (131/268) 현재 주제: Do you take naps?
#
# 질문: Hi, my name is Win and I'm from Vietnam.
# 답변:  Hello, my name is Michael and I'm from Norway.
#
# 질문: Hello, my name is Michael and I'm from Norway.
# 답변:  So, my question is do I take naps?  Well, I do take naps as a habit because in my country for my 12 years of education in Vietnam I have to take nap as compulsory, at least one hour a day. I'm, well, scientifically, I've read that if you take nap it's really good for your brain as it helps you refresh from your half-a-day activity. So, what do you think? Do you take naps?
#
# 질문: So, my question is do I take naps?  Well, I do take naps as a habit because in my country for my 12 years of education in Vietnam I have to take nap as compulsory, at least one hour a day. I'm, well, scientifically, I've read that if you take nap it's really good for your brain as it helps you refresh from your half-a-day activity. So, what do you think? Do you take naps?
# 답변:  I'd love to, sometimes I do and I have problems sleeping because I have insomnia and that makes it harder for me to take naps but whenever I can, you know, taking naps feels really refreshing.
#
# (132/268) 현재 주제: Do you remember your dreams?
#
# 질문: Hi, my name is Win and I'm from Vietnam.
# 답변:  Hi, my name is Goron and I'm from Italy.
#
# 질문: Hi, my name is Goron and I'm from Italy.
# 답변:  So.
#
# 질문: So.
# 답변:  The question is for you, of course, do you remember any dreams?
#
# 질문: The question is for you, of course, do you remember any dreams?
# 답변:  Well, most of the time I forget the dreams that I dreamt about last night but there are some dreams that I still remember. For example, there is one reoccurring dream that I kept seeing, ah, it's kind of a nightmare where my house was burglarized. But I think I had that dream for three or four times in my life but every time that happens in the morning, in the morning are, in the couple of days later I get something really good.
#
# 질문: Well, most of the time I forget the dreams that I dreamt about last night but there are some dreams that I still remember. For example, there is one reoccurring dream that I kept seeing, ah, it's kind of a nightmare where my house was burglarized. But I think I had that dream for three or four times in my life but every time that happens in the morning, in the morning are, in the couple of days later I get something really good.
# 답변:  Thank you.
#
# (133/268) 현재 주제: Buying a used computer?
#
# 질문: Hello, my name is Mark.
# 답변:  And my name is Sorie.
#
# 질문: And my name is Sorie.
# 답변:  Today's question is would you buy a computer second hand?
#
# 질문: Today's question is would you buy a computer second hand?
# 답변:  I would, definitely. I don't mind if it's new or old as long as it works. I'm not picky, how about you?
#
# 질문: I would, definitely. I don't mind if it's new or old as long as it works. I'm not picky, how about you?
# 답변:  Definitely, I'm not picky either. I don't see why I wouldn't buy a computer second hand.
#
# 질문: Definitely, I'm not picky either. I don't see why I wouldn't buy a computer second hand.
# 답변:  Alright.
#
# 질문: Alright.
# 답변:  Case for seeing any problem though?
#
# 질문: Case for seeing any problem though?
# 답변:  I don't think so and they're cheap so I think it's already good.
#
# 질문: I don't think so and they're cheap so I think it's already good.
# 답변:  Cheaper, are they?
#
# 질문: Cheaper, are they?
# 답변:  Yeah.
#
# 질문: Yeah.
# 답변:  So, basically, will you think that buying a computer second hand has no possible problem?
#
# 질문: So, basically, will you think that buying a computer second hand has no possible problem?
# 답변:  No.
#
# 질문: No.
# 답변:  Yeah, great.
#
# (134/268) 현재 주제: Computers vs. teachers?
#
# 질문: Hi, I'm Goron from Italy.
# 답변:  I'm Michael from Norway.
#
# 질문: I'm Michael from Norway.
# 답변:  So, the question is do you think computers can replace teachers?
#
# 질문: So, the question is do you think computers can replace teachers?
# 답변:  That's a good question. No, and why I think that is because, you know, there's only that much you can make interactive without any discipline and I think teacher is the part there that really motivates the students to go further. A computer will never really motivates you, it will only tell you if you're doing good or bad while a teacher can really, you know, tell you about his or her experience, tell you what to do to become better and they will really give you a hint on how to improve yourself in a more humane way.
#
# 질문: That's a good question. No, and why I think that is because, you know, there's only that much you can make interactive without any discipline and I think teacher is the part there that really motivates the students to go further. A computer will never really motivates you, it will only tell you if you're doing good or bad while a teacher can really, you know, tell you about his or her experience, tell you what to do to become better and they will really give you a hint on how to improve yourself in a more humane way.
# 답변:  I agree with you, definitely.
#
# (135/268) 현재 주제: A good place in your country?
#
# (136/268) 현재 주제: What is your country's best city?
#
# (137/268) 현재 주제: What is your favorite music?
#
# 질문: Hello, my name is Michael and I'm from Norway.
# 답변:  Hello, my name is Goran and I'm from Italy.
#
# 질문: Hello, my name is Goran and I'm from Italy.
# 답변:  So, today I'm going to ask, what is your favorite music?
#
# 질문: So, today I'm going to ask, what is your favorite music?
# 답변:  Oh, I would say metal.  Since I was a kid I always love the rock and roll.  And then from rock and roll I passed to some kind of harder rock and roll which is metal. And like it because with the metal, you can try many different subgenre of metal.  It's not just what most of the people think, rumors, there is a lot more about metal we think we have.  So, what about you?
#
# 질문: Oh, I would say metal.  Since I was a kid I always love the rock and roll.  And then from rock and roll I passed to some kind of harder rock and roll which is metal. And like it because with the metal, you can try many different subgenre of metal.  It's not just what most of the people think, rumors, there is a lot more about metal we think we have.  So, what about you?
# 답변:  That's a very good question.  When I was younger, I really love taking on trance.  And then I completely turn to rock and metal and alternative.  And now a days, you know, I like many types of music, I listen to pop, I listen to metal, I listen to techno and trance sometimes.  You know, they say that music tastes is like eating taco, it's to like one genre is like eating taco every day.  So, you should have a mix of everything.  But, yeah, I think rock, I love rock, classic rock, and there, you know, for me it's really important that the song has some kind of message that I agree with or I feel tells me something.
#
# 질문: That's a very good question.  When I was younger, I really love taking on trance.  And then I completely turn to rock and metal and alternative.  And now a days, you know, I like many types of music, I listen to pop, I listen to metal, I listen to techno and trance sometimes.  You know, they say that music tastes is like eating taco, it's to like one genre is like eating taco every day.  So, you should have a mix of everything.  But, yeah, I think rock, I love rock, classic rock, and there, you know, for me it's really important that the song has some kind of message that I agree with or I feel tells me something.
# 답변:  Thank you.
#
# (138/268) 현재 주제: Do you buy music online?
#
# (139/268) 현재 주제: Do you prefer coffee or tea?
#
# (140/268) 현재 주제: What is your dream job?
#
# (141/268) 현재 주제: Do you like traveling?
#
# (142/268) 현재 주제: What is a good vacation spot?
#
# (143/268) 현재 주제: Education in your Country
#
# (144/268) 현재 주제: How is education in your country?
#
# (145/268) 현재 주제: Glasses or Contacts?
#
# (146/268) 현재 주제: How good is your eyesight?
#
# 질문: And my name is Sorie, and today's question is how good is your eyesight?
# 답변:  My eyesight? I don't wear glasses actually. My eyesight I would say is extremely good.
#
# 질문: My eyesight? I don't wear glasses actually. My eyesight I would say is extremely good.
# 답변:  Wow!
#
# 질문: Wow!
# 답변:  How about you?
#
# 질문: How about you?
# 답변:  Mine is terrible. I actually need contact lenses. And if I don't have my contact lenses on I cannot even walk properly. I would bump into door and walls. That's how bad it is.
#
# 질문: Mine is terrible. I actually need contact lenses. And if I don't have my contact lenses on I cannot even walk properly. I would bump into door and walls. That's how bad it is.
# 답변:  Are you long-sighted or short-sighted?
#
# 질문: Are you long-sighted or short-sighted?
# 답변:  Long-sighted.
#
# 질문: Long-sighted.
# 답변:  What does that mean?
#
# 질문: What does that mean?
# 답변:  You can't see far away. Yeah. Really Bad!
#
# (147/268) 현재 주제: Good Cuisine from your Country
# (148/268) 현재 주제: Does your country have good food?
#
# (149/268) 현재 주제: Is it cheap where you live?
#
# (150/268) 현재 주제: Would you rather work for a large or small company?
#
# 질문: Hello, this is the video for ello.org. Iâm  from Thailand.
# 답변:  And Iâm Micky from Nigeria.
#
# 질문: And Iâm Micky from Nigeria.
# 답변:  Uhm, the question is about âWould you rather work for a large or small company?â Would you?
#
# 질문: Uhm, the question is about âWould you rather work for a large or small company?â Would you?
# 답변:  Yeah, I donât know, but I think I would rather work for a large company.
#
# 질문: Yeah, I donât know, but I think I would rather work for a large company.
# 답변:  Uhm, why?
#
# 질문: Uhm, why?
# 답변:  Because working for a large company gives you room to build yourself. Have large friends, have large organization to work with because youâre kind of like reckon with and all that.
#
# 질문: Because working for a large company gives you room to build yourself. Have large friends, have large organization to work with because youâre kind of like reckon with and all that.
# 답변:  Well, if itâs me, I would rather work for a small company, because like, I see when I feel that if you work in a large company there, there is more rules and regulations. But if it is a small company you can, I can move more freely. And I suppose maybe that my opinion can be heard easier than in a large company where higher ups are far away in maybe some another foreign country.
#
# 질문: Well, if itâs me, I would rather work for a small company, because like, I see when I feel that if you work in a large company there, there is more rules and regulations. But if it is a small company you can, I can move more freely. And I suppose maybe that my opinion can be heard easier than in a large company where higher ups are far away in maybe some another foreign country.
# 답변:  Yeah, but to large company, you have a chance of working withâ¦.
#
# 질문: Yeah, but to large company, you have a chance of working withâ¦.
# 답변:  Yeah
#
# 질문: Yeah
# 답변:  all that new people and you can make a lot of large friends, you know.
#
# 질문: all that new people and you can make a lot of large friends, you know.
# 답변:  Yeah.
#
# 질문: Yeah.
# 답변:  And a good network too.
#
# 질문: And a good network too.
# 답변:  Weâll see.
#
# (151/268) 현재 주제: Have you ever been the boss?
#
# (152/268) 현재 주제: Have you ever been in an accident?
#
# (153/268) 현재 주제: Do you have an accident story?
#
# (154/268) 현재 주제: How do people show affection in your country?
#
# (155/268) 현재 주제: Do you have special childhood memories?
#
# (156/268) 현재 주제: Could you live on a secluded island?
#
# (157/268) 현재 주제: Could you live on a secluded island?
#
# (158/268) 현재 주제: Do you eat out often?
#
# (159/268) 현재 주제: How often do you eat fast food?
#
# (160/268) 현재 주제: Are there any wild animals where you live?
#
# (161/268) 현재 주제: Is there wildlife in your area?
#
# (162/268) 현재 주제: How is the weather today?
#
# (163/268) 현재 주제: What is your favorite season?
#
# (164/268) 현재 주제: Has your country changed?
#
# (165/268) 현재 주제: What is your best childhood memory?
#
# (166/268) 현재 주제: Do you worry about money?
#
# (167/268) 현재 주제: Do you want a big or small family?
#
# (168/268) 현재 주제: Do you like to be alone in the wild?
#
# (169/268) 현재 주제: What is the meaning of life?
#
# (170/268) 현재 주제: Do you want to travel?
#
# (171/268) 현재 주제: What do you like about your city?
#
# (172/268) 현재 주제: Using Air-Con
#
# (173/268) 현재 주제: Global Warming
#
# (174/268) 현재 주제: What is on your bucket list?
#
# (175/268) 현재 주제: Do you remember your dreams?
#
# (176/268) 현재 주제: Do you get enough sleep?
#
# (177/268) 현재 주제: What is your dream house?
#
# 질문: Hello everyone. My name is Adiba and I'm from Tajikistan.
# 답변:  Abidemi from Nigeria.
#
# 질문: Abidemi from Nigeria.
# 답변:  The question is; what would your dream home have?
#
# 질문: The question is; what would your dream home have?
# 답변:  Well for me, I have this dream since I was a kid that I would like a home with a shower where you can listen to music.
#
# 질문: Well for me, I have this dream since I was a kid that I would like a home with a shower where you can listen to music.
# 답변:  Wow.
#
# 질문: Wow.
# 답변:  Yes.
#
# 질문: Yes.
# 답변:  So this is fancy.
#
# 질문: So this is fancy.
# 답변:  I love listening to music and for me, there's nothing more relaxing than having a song that I really like or even songs that I really like while I'm taking a shower.
#
# 질문: I love listening to music and for me, there's nothing more relaxing than having a song that I really like or even songs that I really like while I'm taking a shower.
# 답변:  In the shower?
#
# ...
#
# 질문: As far as I remember and think back, I can't remember I've ever been or heard about any regulations whatsoever about which clothes you can wear, and which clothes you cannot. However, I still think that ... everybody thinks about, most people at least think about what clothes would not be the thing to wear today for class and et cetera, but no, not in terms of regulations, not in terms of any rules no. But do you think there should be rules, so should it be more like decide yourself?
# 답변:  I think it was good to have some rules, but at the same time it was really like restrictive and people were like going against it, like an act of rebelion, so the more you repress them, they won't actually wear those clothes, so as soon as they were out of those schools, they were completely wearing it in an extreme way, so I'm not sure if it's a good idea, especially in high school, where people try to find themselves, and they actually construct themselves in a rebellious way, so maybe not.
#
# 질문: I think it was good to have some rules, but at the same time it was really like restrictive and people were like going against it, like an act of rebelion, so the more you repress them, they won't actually wear those clothes, so as soon as they were out of those schools, they were completely wearing it in an extreme way, so I'm not sure if it's a good idea, especially in high school, where people try to find themselves, and they actually construct themselves in a rebellious way, so maybe not.
# 답변:  Maybe not. Maybe not. But anyhow, how does it work in your country? Are people allowed to dress risky or inappropriate in any way? And does it happen?
#
# (250/268) 현재 주제: Do students dress appropriately?
#
# 질문: Hello, I'm Lucille from France.
# 답변:  And hello, my name is Lasse, and I come from Denmark. And today's question is do students in your dress inappropriately? Do they do that in France?
#
# 질문: And hello, my name is Lasse, and I come from Denmark. And today's question is do students in your dress inappropriately? Do they do that in France?
# 답변:  Actually, I think it really depends on the age because if we just talk about school as we are talking about students, it is true that in high school, in main high school we have really strict rules. That means you sign a contract when you go to the school, saying that for girls for example, you won't show too much of your shoulders, or you won't like skirts that are like too short, and for guys you can't have like pants with a hole where you can see stuff. You really need to dress like properly, and actually if you don't you receive like some sanction. You need to go home and change yourself, and it's written in your file. That's really about high school, so I don't know about Denmark.
#
# 질문: Actually, I think it really depends on the age because if we just talk about school as we are talking about students, it is true that in high school, in main high school we have really strict rules. That means you sign a contract when you go to the school, saying that for girls for example, you won't show too much of your shoulders, or you won't like skirts that are like too short, and for guys you can't have like pants with a hole where you can see stuff. You really need to dress like properly, and actually if you don't you receive like some sanction. You need to go home and change yourself, and it's written in your file. That's really about high school, so I don't know about Denmark.
# 답변:  As far as I remember and think back, I can't remember I've ever been or heard about any regulations whatsoever about which clothes you can wear, and which clothes you cannot. However, I still think that ... everybody thinks about, most people at least think about what clothes would not be the thing to wear today for class and et cetera, but no, not in terms of regulations, not in terms of any rules no. But do you think there should be rules, so should it be more like decide yourself?
#
# 질문: As far as I remember and think back, I can't remember I've ever been or heard about any regulations whatsoever about which clothes you can wear, and which clothes you cannot. However, I still think that ... everybody thinks about, most people at least think about what clothes would not be the thing to wear today for class and et cetera, but no, not in terms of regulations, not in terms of any rules no. But do you think there should be rules, so should it be more like decide yourself?
# 답변:  I think it was good to have some rules, but at the same time it was really like restrictive and people were like going against it, like an act of rebelion, so the more you repress them, they won't actually wear those clothes, so as soon as they were out of those schools, they were completely wearing it in an extreme way, so I'm not sure if it's a good idea, especially in high school, where people try to find themselves, and they actually construct themselves in a rebellious way, so maybe not.
#
# 질문: I think it was good to have some rules, but at the same time it was really like restrictive and people were like going against it, like an act of rebelion, so the more you repress them, they won't actually wear those clothes, so as soon as they were out of those schools, they were completely wearing it in an extreme way, so I'm not sure if it's a good idea, especially in high school, where people try to find themselves, and they actually construct themselves in a rebellious way, so maybe not.
# 답변:  Maybe not. Maybe not. But anyhow, how does it work in your country? Are people allowed to dress risky or inappropriate in any way? And does it happen?
#
# (251/268) 현재 주제: What do you think of beauty pageants?
# (252/268) 현재 주제: Do you like beauty pageants?
#
# (253/268) 현재 주제: Do you worry about your looks?
#
# (254/268) 현재 주제: Are you good with children?
#
# 질문: Hi! This is Hanna, from Australia.
# 답변:  And this is Paul, from South Korea.
#
# 질문: And this is Paul, from South Korea.
# 답변:  So, Paul! Are you good with children?
#
# 질문: So, Paul! Are you good with children?
# 답변:  I think I'm good with children.
#
# 질문: I think I'm good with children.
# 답변:  Oh, really?
#
# 질문: Oh, really?
# 답변:  I really enjoy hanging out with them. Some people say I'm a bit childish, that's why I get along with kids so well.
#
# 질문: I really enjoy hanging out with them. Some people say I'm a bit childish, that's why I get along with kids so well.
# 답변:  Oh, really?
#
# 질문: Oh, really?
# 답변:  Oh yeah, I do enjoy hanging out with them. I mean, the way they play...
#
# 질문: Oh yeah, I do enjoy hanging out with them. I mean, the way they play...
# 답변:  Yeah?
#
# 질문: Yeah?
# 답변:  Like throwing balls at each other, and like all the sports and all the toys...
#
# 질문: Like throwing balls at each other, and like all the sports and all the toys...
# 답변:  Yeah, you seem like the kind of guy who gets along well with children, actually.
#
# 질문: Yeah, you seem like the kind of guy who gets along well with children, actually.
# 답변:  I do. I do.
#
# (255/268) 현재 주제: What is your favorite food?
#
# (256/268) 현재 주제: Do you like to travel alone?
#
# (257/268) 현재 주제: Where would you like to travel?
#
# (258/268) 현재 주제: Are you prepated for a natural disater?
#
# (259/268) 현재 주제: Have you been stopped by the police?
#
# 질문: Hello, I'm Paul from South Korea.
# 답변:  And I'm Hanna from Australia.
#
# 질문: And I'm Hanna from Australia.
# 답변:  So Hanna, have you ever been stopped by police before?
#
# 질문: So Hanna, have you ever been stopped by police before?
# 답변:  Ah, yeah, actually I have once. I got a speeding ticket one time.
#
# 질문: Ah, yeah, actually I have once. I got a speeding ticket one time.
# 답변:  Were you driving?
#
# 질문: Were you driving?
# 답변:  Yeah, I was driving a scooter, and well I was going a little bit too fast. And the police ...
#
# 질문: Yeah, I was driving a scooter, and well I was going a little bit too fast. And the police ...
# 답변:  "A little bit too fast"
#
# 질문: "A little bit too fast"
# 답변:  A little bit too fast, and the police were around the corner and they have the speed camera and they picked me up on that and pulled me over and ...
#
# 질문: A little bit too fast, and the police were around the corner and they have the speed camera and they picked me up on that and pulled me over and ...
# 답변:  Did you pay a find?
#
# 질문: Did you pay a find?
# 답변:  Yes. I did. I had to pay a fine, and I was very sad to do that.
#
# 질문: Yes. I did. I had to pay a fine, and I was very sad to do that.
# 답변:  Yeah, I don't like the paying money part.
#
# 질문: Yeah, I don't like the paying money part.
# 답변:  OK, maybe you shouldn't drive then.
#
# 질문: OK, maybe you shouldn't drive then.
# 답변:  I can drive, but I'm not going to drive that fast.
#
# 질문: I can drive, but I'm not going to drive that fast.
# 답변:  OK. Then maybe you should drive, safely and slowly.
#
# 질문: OK. Then maybe you should drive, safely and slowly.
# 답변:  Safely and slowly.
#
# 질문: Safely and slowly.
# 답변:  OK.
#
# (260/268) 현재 주제: Have you had a bad job?
#
# 질문: Hello, this is Diego from Mexico.
# 답변:  Hi, I'm Silvia from Guatemala.
#
# 질문: Hi, I'm Silvia from Guatemala.
# 답변:  And I want to ask you a question. Can you tell me about your worst job ever?
#
# 질문: And I want to ask you a question. Can you tell me about your worst job ever?
# 답변:  Yeah, I had a really bad job. I was there for two months. Have you seen the movie The Devil Wears Prada?
#
# 질문: Yeah, I had a really bad job. I was there for two months. Have you seen the movie The Devil Wears Prada?
# 답변:  Yes.
#
# 질문: Yes.
# 답변:  Well, that movie reminds me of my job.
#
# 질문: Well, that movie reminds me of my job.
# 답변:  Really?
#
# 질문: Really?
# 답변:  Imagine.
#
# 질문: Imagine.
# 답변:  Why?
#
# 질문: Why?
# 답변:  Because my boss was the devil. He was. Actually, it was a very exhausting job, and you had to be there by seven a.m. until five. I never left after five. I alwasy. I'm sorry, I never...
#
# 질문: Because my boss was the devil. He was. Actually, it was a very exhausting job, and you had to be there by seven a.m. until five. I never left after five. I alwasy. I'm sorry, I never...
# 답변:  before five.
#
# 질문: before five.
# 답변:  before five. I always left around six, and still you had to go on Saturday half a day
#
# 질문: before five. I always left around six, and still you had to go on Saturday half a day
# 답변:  Oh, and what was this job for?
#
# 질문: Oh, and what was this job for?
# 답변:  Actually, it's a clothing chain in Guatemala. It's quite famous, so they have around 80 stores, and the job was in marketing, and the boss was just ...
#
# 질문: Actually, it's a clothing chain in Guatemala. It's quite famous, so they have around 80 stores, and the job was in marketing, and the boss was just ...
# 답변:  too demanding.
#
# 질문: too demanding.
# 답변:  And even a little bit, how do you say, like the way of treating people was not nice at all. Like he would even tell you, like, "Are you stupid or what?"
#
# 질문: And even a little bit, how do you say, like the way of treating people was not nice at all. Like he would even tell you, like, "Are you stupid or what?"
# 답변:  Wow, that sounds horrible
#
# 질문: Wow, that sounds horrible
# 답변:  It was horrible. So that's why the Devil Wears Prada is one of my favorite movies. It just reminds me of my job.
#
# 질문: It was horrible. So that's why the Devil Wears Prada is one of my favorite movies. It just reminds me of my job.
# 답변:  Oh!
#
# 질문: Oh!
# 답변:  I even had nightmares of my boss after quitting.
#
# 질문: I even had nightmares of my boss after quitting.
# 답변:  Wow!
#
# 질문: Wow!
# 답변:  Imagine. It was a really bad job.
#
# (261/268) 현재 주제: Have you had a really bad day?
#
# 질문: Hi, my name is Silvia. I'm from Gautemala.
# 답변:  And my name is Diego. I'm from Mexico.
#
# 질문: And my name is Diego. I'm from Mexico.
# 답변:  Diego, I want to ask you something. Have you ever had a really bad job?
#
# 질문: Diego, I want to ask you something. Have you ever had a really bad job?
# 답변:  I don't think I've had a bad job, but I had a really bad experience while working. And I was working at the World Trade Organization, and it's a very intense place to work at, and what happened is that my boss had a back problem, so one day his back really, really hurt, and we were a bit late for a meeting, but we needed coffee because when you're working you need coffee.
#
# 질문: I don't think I've had a bad job, but I had a really bad experience while working. And I was working at the World Trade Organization, and it's a very intense place to work at, and what happened is that my boss had a back problem, so one day his back really, really hurt, and we were a bit late for a meeting, but we needed coffee because when you're working you need coffee.
# 답변:  Of course.
#
# 질문: Of course.
# 답변:  So we went to buy coffee at the cafeteria, and I asked him if I should carry his bag, and he said yes because he has the back problem, so I was carrying his bag, my bag and files, because I was an intern.
#
# 질문: So we went to buy coffee at the cafeteria, and I asked him if I should carry his bag, and he said yes because he has the back problem, so I was carrying his bag, my bag and files, because I was an intern.
# 답변:  Don't tell me you spilled the coffee on the files?
#
# 질문: Don't tell me you spilled the coffee on the files?
# 답변:  No.
#
# 질문: No.
# 답변:  OK.
#
# 질문: OK.
# 답변:  It's even worse.
#
# 질문: It's even worse.
# 답변:  Worse?
#
# 질문: Worse?
# 답변:  Worse!
#
# 질문: Worse!
# 답변:  Oh my God!
#
# 질문: Oh my God!
# 답변:  I was carrying, files, and two laptops, or two bags and what happened is that it was a meeting. It was a very important meeting with representatives from 153 different countries, and we were inside the meeting room and it's long, long, long, long tables with chairs on each side. And I was staggering through the chairs, and what happened is that I was holding the coffee, and then my bag fell from my shoulder to my elbow. And the coffee just went like Vhoo inside the meeting room, and it landed on the representative from India and ...
#
# 질문: I was carrying, files, and two laptops, or two bags and what happened is that it was a meeting. It was a very important meeting with representatives from 153 different countries, and we were inside the meeting room and it's long, long, long, long tables with chairs on each side. And I was staggering through the chairs, and what happened is that I was holding the coffee, and then my bag fell from my shoulder to my elbow. And the coffee just went like Vhoo inside the meeting room, and it landed on the representative from India and ...
# 답변:  Oh, my gosh!
#
# 질문: Oh, my gosh!
# 답변:  It was horrible because we were there late, so the meeting was going on, and I spilled the coffee, burning hot coffee on the guy from India. He just jumped and he screamed, and everybody was just looking at me, and I think it's one of the most embarrassing moments in my life.
#
# 질문: It was horrible because we were there late, so the meeting was going on, and I spilled the coffee, burning hot coffee on the guy from India. He just jumped and he screamed, and everybody was just looking at me, and I think it's one of the most embarrassing moments in my life.
# 답변:  It is actually.
#
# (262/268) 현재 주제: Do you want a pet?
# (263/268) 현재 주제: What business would you like to start?
#
# (264/268) 현재 주제: What is the best thing about your country?
#
# (265/268) 현재 주제: What is the best thing about your country?
#
# (266/268) 현재 주제: What are you cooking?
#
# 질문: Hey I say, what are you doing?
# 답변:   I'm making some lunch. We are very busy now because we have to study for exams so I'm making something very quick. It's just some meat with salad and potatoes that are even not peeled if you look at it. Actually, I don't have myself eating potatoes in so hot climate because it's very hard to digest but Krustoff likes it a lot so we make everything together and then we'll see who eats what. I kind of like this food, it's enough for a day.
#
# (267/268) 현재 주제: What are your favorite things?
#
# 전체 대화 주제의 개수는 402개 입니다.

# %%
import xlsxwriter

# 엑셀 워크 북 및 워크 시트를 생성합니다.
workbook = xlsxwriter.Workbook('Conversation Data 2.xlsx')
worksheet = workbook.add_worksheet()

row = 0
col = 0

# 모든 대화 내용을 엑셀로 저장합니다.
for c in conversations:
    worksheet.write(row, col, c.contentName)
    worksheet.write(row, col + 1, c.contentType)
    worksheet.write(row, col + 2, c.question)
    worksheet.write(row, col + 3, c.answer)
    row = row + 1
    
workbook.close()

# %%
# 내보내기 이후에 엑셀에서 공백이 있거나 None으로 처리된 것들은 제거합니다.
